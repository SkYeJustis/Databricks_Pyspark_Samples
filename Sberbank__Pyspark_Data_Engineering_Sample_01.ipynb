# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %% [markdown]
# ## STAGING DATA
# ### Raw CSV -> Raw PARQUET (Optional depending on file size. Affects processing time needed for transformation.)

# %%
# Sberbank Russian Housing Market
# https://www.kaggle.com/c/sberbank-russian-housing-market
# Training.csv and Macro.csv was used in this data engineering flow example

# File location and type
file_location = "/FileStore/tables/train.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df1 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>timestamp</th><th>full_sq</th><th>life_sq</th><th>floor</th><th>max_floor</th><th>material</th><th>build_year</th><th>num_room</th><th>kitch_sq</th><th>state</th><th>product_type</th><th>sub_area</th><th>area_m</th><th>raion_popul</th><th>green_zone_part</th><th>indust_part</th><th>children_preschool</th><th>preschool_quota</th><th>preschool_education_centers_raion</th><th>children_school</th><th>school_quota</th><th>school_education_centers_raion</th><th>school_education_centers_top_20_raion</th><th>hospital_beds_raion</th><th>healthcare_centers_raion</th><th>university_top_20_raion</th><th>sport_objects_raion</th><th>additional_education_raion</th><th>culture_objects_top_25</th><th>culture_objects_top_25_raion</th><th>shopping_centers_raion</th><th>office_raion</th><th>thermal_power_plant_raion</th><th>incineration_raion</th><th>oil_chemistry_raion</th><th>radiation_raion</th><th>railroad_terminal_raion</th><th>big_market_raion</th><th>nuclear_reactor_raion</th><th>detention_facility_raion</th><th>full_all</th><th>male_f</th><th>female_f</th><th>young_all</th><th>young_male</th><th>young_female</th><th>work_all</th><th>work_male</th><th>work_female</th><th>ekder_all</th><th>ekder_male</th><th>ekder_female</th><th>0_6_all</th><th>0_6_male</th><th>0_6_female</th><th>7_14_all</th><th>7_14_male</th><th>7_14_female</th><th>0_17_all</th><th>0_17_male</th><th>0_17_female</th><th>16_29_all</th><th>16_29_male</th><th>16_29_female</th><th>0_13_all</th><th>0_13_male</th><th>0_13_female</th><th>raion_build_count_with_material_info</th><th>build_count_block</th><th>build_count_wood</th><th>build_count_frame</th><th>build_count_brick</th><th>build_count_monolith</th><th>build_count_panel</th><th>build_count_foam</th><th>build_count_slag</th><th>build_count_mix</th><th>raion_build_count_with_builddate_info</th><th>build_count_before_1920</th><th>build_count_1921-1945</th><th>build_count_1946-1970</th><th>build_count_1971-1995</th><th>build_count_after_1995</th><th>ID_metro</th><th>metro_min_avto</th><th>metro_km_avto</th><th>metro_min_walk</th><th>metro_km_walk</th><th>kindergarten_km</th><th>school_km</th><th>park_km</th><th>green_zone_km</th><th>industrial_km</th><th>water_treatment_km</th><th>cemetery_km</th><th>incineration_km</th><th>railroad_station_walk_km</th><th>railroad_station_walk_min</th><th>ID_railroad_station_walk</th><th>railroad_station_avto_km</th><th>railroad_station_avto_min</th><th>ID_railroad_station_avto</th><th>public_transport_station_km</th><th>public_transport_station_min_walk</th><th>water_km</th><th>water_1line</th><th>mkad_km</th><th>ttk_km</th><th>sadovoe_km</th><th>bulvar_ring_km</th><th>kremlin_km</th><th>big_road1_km</th><th>ID_big_road1</th><th>big_road1_1line</th><th>big_road2_km</th><th>ID_big_road2</th><th>railroad_km</th><th>railroad_1line</th><th>zd_vokzaly_avto_km</th><th>ID_railroad_terminal</th><th>bus_terminal_avto_km</th><th>ID_bus_terminal</th><th>oil_chemistry_km</th><th>nuclear_reactor_km</th><th>radiation_km</th><th>power_transmission_line_km</th><th>thermal_power_plant_km</th><th>ts_km</th><th>big_market_km</th><th>market_shop_km</th><th>fitness_km</th><th>swim_pool_km</th><th>ice_rink_km</th><th>stadium_km</th><th>basketball_km</th><th>hospice_morgue_km</th><th>detention_facility_km</th><th>public_healthcare_km</th><th>university_km</th><th>workplaces_km</th><th>shopping_centers_km</th><th>office_km</th><th>additional_education_km</th><th>preschool_km</th><th>big_church_km</th><th>church_synagogue_km</th><th>mosque_km</th><th>theater_km</th><th>museum_km</th><th>exhibition_km</th><th>catering_km</th><th>ecology</th><th>green_part_500</th><th>prom_part_500</th><th>office_count_500</th><th>office_sqm_500</th><th>trc_count_500</th><th>trc_sqm_500</th><th>cafe_count_500</th><th>cafe_sum_500_min_price_avg</th><th>cafe_sum_500_max_price_avg</th><th>cafe_avg_price_500< ...

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "sberbank_housing"
df1.write.format("parquet").mode('overwrite').saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Sberbank Russian Housing Market
# https://www.kaggle.com/c/sberbank-russian-housing-market

# File location and type
file_location = "/FileStore/tables/macro.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df2 = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>oil_urals</th><th>gdp_quart</th><th>gdp_quart_growth</th><th>cpi</th><th>ppi</th><th>gdp_deflator</th><th>balance_trade</th><th>balance_trade_growth</th><th>usdrub</th><th>eurrub</th><th>brent</th><th>net_capital_export</th><th>gdp_annual</th><th>gdp_annual_growth</th><th>average_provision_of_build_contract</th><th>average_provision_of_build_contract_moscow</th><th>rts</th><th>micex</th><th>micex_rgbi_tr</th><th>micex_cbi_tr</th><th>deposits_value</th><th>deposits_growth</th><th>deposits_rate</th><th>mortgage_value</th><th>mortgage_growth</th><th>mortgage_rate</th><th>grp</th><th>grp_growth</th><th>income_per_cap</th><th>real_dispos_income_per_cap_growth</th><th>salary</th><th>salary_growth</th><th>fixed_basket</th><th>retail_trade_turnover</th><th>retail_trade_turnover_per_cap</th><th>retail_trade_turnover_growth</th><th>labor_force</th><th>unemployment</th><th>employment</th><th>invest_fixed_capital_per_cap</th><th>invest_fixed_assets</th><th>profitable_enterpr_share</th><th>unprofitable_enterpr_share</th><th>share_own_revenues</th><th>overdue_wages_per_cap</th><th>fin_res_per_cap</th><th>marriages_per_1000_cap</th><th>divorce_rate</th><th>construction_value</th><th>invest_fixed_assets_phys</th><th>pop_natural_increase</th><th>pop_migration</th><th>pop_total_inc</th><th>childbirth</th><th>mortality</th><th>housing_fund_sqm</th><th>lodging_sqm_per_cap</th><th>water_pipes_share</th><th>baths_share</th><th>sewerage_share</th><th>gas_share</th><th>hot_water_share</th><th>electric_stove_share</th><th>heating_share</th><th>old_house_share</th><th>average_life_exp</th><th>infant_mortarity_per_1000_cap</th><th>perinatal_mort_per_1000_cap</th><th>incidence_population</th><th>rent_price_4+room_bus</th><th>rent_price_3room_bus</th><th>rent_price_2room_bus</th><th>rent_price_1room_bus</th><th>rent_price_3room_eco</th><th>rent_price_2room_eco</th><th>rent_price_1room_eco</th><th>load_of_teachers_preschool_per_teacher</th><th>child_on_acc_pre_school</th><th>load_of_teachers_school_per_teacher</th><th>students_state_oneshift</th><th>modern_education_share</th><th>old_education_build_share</th><th>provision_doctors</th><th>provision_nurse</th><th>load_on_doctors</th><th>power_clinics</th><th>hospital_beds_available_per_cap</th><th>hospital_bed_occupancy_per_year</th><th>provision_retail_space_sqm</th><th>provision_retail_space_modern_sqm</th><th>turnover_catering_per_cap</th><th>theaters_viewers_per_1000_cap</th><th>seats_theather_rfmin_per_100000_cap</th><th>museum_visitis_per_100_cap</th><th>bandwidth_sports</th><th>population_reg_sports_share</th><th>students_reg_sports_share</th><th>apartment_build</th><th>apartment_fund_sqm</th></tr></thead><tbody><tr><td>2010-01-01T00:00:00.000+0000</td><td>76.1</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>38807.2</td><td>-0.078208582</td><td>5.0</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>7484970</td><td>NA</td><td>NA</td><td>142968</td><td>NA</td><td>13.72</td><td>8375.8638</td><td>NA</td><td>30789.2</td><td>0.038</td><td>38410.5</td><td>NA</td><td>11443.63</td><td>2882.4169</td><td>251.484</td><td>106.8</td><td>6436.244</td><td>0.018</td><td>0.69</td><td>63932</td><td>732.760604</td><td>0.716</td><td>0.284</td><td>0.962915058</td><td>12865</td><td>233.3515293</td><td>8</td><td>3.9</td><td>553874.9</td><td>95.8</td><td>-0.3</td><td>14.1</td><td>13.8</td><td>10.7</td><td>11</td><td>216</td><td>18.71588251</td><td>99.9</td><td>99.8</td><td>99.6</td><td>44.4</td><td>95.7</td><td>55</td><td>99.9</td><td>0.3</td><td>74.2</td><td>6.1</td><td>5.87</td><td>696.6</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td><td>721.4777653</td><td>45,713</td><td>1356.112607</td><td>NA</td><td>NA</td><td>NA</td><td>18</td><td>99.4</td><td>7872.848285</td> ...

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "macro"
df2.write.format("parquet").mode('overwrite').saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Cleanup
del df1
del df2
del permanent_table_name
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## TRANSFORMATION
# ### Raw CSV or Raw PARQUET -> Parquet

# %%
macro =spark.sql("SELECT * FROM macro")
print(macro.count())
print(macro.dtypes)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2484
# [(&apos;timestamp&apos;, &apos;timestamp&apos;), (&apos;oil_urals&apos;, &apos;double&apos;), (&apos;gdp_quart&apos;, &apos;string&apos;), (&apos;gdp_quart_growth&apos;, &apos;string&apos;), (&apos;cpi&apos;, &apos;string&apos;), (&apos;ppi&apos;, &apos;string&apos;), (&apos;gdp_deflator&apos;, &apos;string&apos;), (&apos;balance_trade&apos;, &apos;string&apos;), (&apos;balance_trade_growth&apos;, &apos;string&apos;), (&apos;usdrub&apos;, &apos;string&apos;), (&apos;eurrub&apos;, &apos;string&apos;), (&apos;brent&apos;, &apos;string&apos;), (&apos;net_capital_export&apos;, &apos;string&apos;), (&apos;gdp_annual&apos;, &apos;double&apos;), (&apos;gdp_annual_growth&apos;, &apos;double&apos;), (&apos;average_provision_of_build_contract&apos;, &apos;double&apos;), (&apos;average_provision_of_build_contract_moscow&apos;, &apos;string&apos;), (&apos;rts&apos;, &apos;string&apos;), (&apos;micex&apos;, &apos;string&apos;), (&apos;micex_rgbi_tr&apos;, &apos;string&apos;), (&apos;micex_cbi_tr&apos;, &apos;string&apos;), (&apos;deposits_value&apos;, &apos;int&apos;), (&apos;deposits_growth&apos;, &apos;string&apos;), (&apos;deposits_rate&apos;, &apos;string&apos;), (&apos;mortgage_value&apos;, &apos;int&apos;), (&apos;mortgage_growth&apos;, &apos;string&apos;), (&apos;mortgage_rate&apos;, &apos;double&apos;), (&apos;grp&apos;, &apos;string&apos;), (&apos;grp_growth&apos;, &apos;string&apos;), (&apos;income_per_cap&apos;, &apos;string&apos;), (&apos;real_dispos_income_per_cap_growth&apos;, &apos;string&apos;), (&apos;salary&apos;, &apos;string&apos;), (&apos;salary_growth&apos;, &apos;string&apos;), (&apos;fixed_basket&apos;, &apos;double&apos;), (&apos;retail_trade_turnover&apos;, &apos;string&apos;), (&apos;retail_trade_turnover_per_cap&apos;, &apos;string&apos;), (&apos;retail_trade_turnover_growth&apos;, &apos;string&apos;), (&apos;labor_force&apos;, &apos;string&apos;), (&apos;unemployment&apos;, &apos;string&apos;), (&apos;employment&apos;, &apos;string&apos;), (&apos;invest_fixed_capital_per_cap&apos;, &apos;string&apos;), (&apos;invest_fixed_assets&apos;, &apos;string&apos;), (&apos;profitable_enterpr_share&apos;, &apos;string&apos;), (&apos;unprofitable_enterpr_share&apos;, &apos;string&apos;), (&apos;share_own_revenues&apos;, &apos;string&apos;), (&apos;overdue_wages_per_cap&apos;, &apos;string&apos;), (&apos;fin_res_per_cap&apos;, &apos;string&apos;), (&apos;marriages_per_1000_cap&apos;, &apos;string&apos;), (&apos;divorce_rate&apos;, &apos;string&apos;), (&apos;construction_value&apos;, &apos;string&apos;), (&apos;invest_fixed_assets_phys&apos;, &apos;string&apos;), (&apos;pop_natural_increase&apos;, &apos;string&apos;), (&apos;pop_migration&apos;, &apos;string&apos;), (&apos;pop_total_inc&apos;, &apos;string&apos;), (&apos;childbirth&apos;, &apos;string&apos;), (&apos;mortality&apos;, &apos;string&apos;), (&apos;housing_fund_sqm&apos;, &apos;string&apos;), (&apos;lodging_sqm_per_cap&apos;, &apos;string&apos;), (&apos;water_pipes_share&apos;, &apos;string&apos;), (&apos;baths_share&apos;, &apos;string&apos;), (&apos;sewerage_share&apos;, &apos;string&apos;), (&apos;gas_share&apos;, &apos;string&apos;), (&apos;hot_water_share&apos;, &apos;string&apos;), (&apos;electric_stove_share&apos;, &apos;string&apos;), (&apos;heating_share&apos;, &apos;string&apos;), (&apos;old_house_share&apos;, &apos;string&apos;), (&apos;average_life_exp&apos;, &apos;string&apos;), (&apos;infant_mortarity_per_1000_cap&apos;, &apos;string&apos;), (&apos;perinatal_mort_per_1000_cap&apos;, &apos;string&apos;), (&apos;incidence_population&apos;, &apos;string&apos;), (&apos;rent_price_4+room_bus&apos;, &apos;string&apos;), (&apos;rent_price_3room_bus&apos;, &apos;string&apos;), (&apos;rent_price_2room_bus&apos;, &apos;string&apos;), (&apos;rent_price_1room_bus&apos;, &apos;string&apos;), (&apos;rent_price_3room_eco&apos;, &apos;string&apos;), (&apos;rent_price_2room_eco&apos;, &apos;string&apos;), (&apos;rent_price_1room_eco&apos;, &apos;string&apos;), (&ap ...
# </div>

# %%
sberbank_housing =spark.sql("SELECT * FROM sberbank_housing")
print(sberbank_housing.count())
print(sberbank_housing.dtypes)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">30471
# [(&apos;id&apos;, &apos;int&apos;), (&apos;timestamp&apos;, &apos;timestamp&apos;), (&apos;full_sq&apos;, &apos;int&apos;), (&apos;life_sq&apos;, &apos;string&apos;), (&apos;floor&apos;, &apos;string&apos;), (&apos;max_floor&apos;, &apos;string&apos;), (&apos;material&apos;, &apos;string&apos;), (&apos;build_year&apos;, &apos;string&apos;), (&apos;num_room&apos;, &apos;string&apos;), (&apos;kitch_sq&apos;, &apos;string&apos;), (&apos;state&apos;, &apos;string&apos;), (&apos;product_type&apos;, &apos;string&apos;), (&apos;sub_area&apos;, &apos;string&apos;), (&apos;area_m&apos;, &apos;double&apos;), (&apos;raion_popul&apos;, &apos;int&apos;), (&apos;green_zone_part&apos;, &apos;double&apos;), (&apos;indust_part&apos;, &apos;double&apos;), (&apos;children_preschool&apos;, &apos;int&apos;), (&apos;preschool_quota&apos;, &apos;string&apos;), (&apos;preschool_education_centers_raion&apos;, &apos;int&apos;), (&apos;children_school&apos;, &apos;int&apos;), (&apos;school_quota&apos;, &apos;string&apos;), (&apos;school_education_centers_raion&apos;, &apos;int&apos;), (&apos;school_education_centers_top_20_raion&apos;, &apos;int&apos;), (&apos;hospital_beds_raion&apos;, &apos;string&apos;), (&apos;healthcare_centers_raion&apos;, &apos;int&apos;), (&apos;university_top_20_raion&apos;, &apos;int&apos;), (&apos;sport_objects_raion&apos;, &apos;int&apos;), (&apos;additional_education_raion&apos;, &apos;int&apos;), (&apos;culture_objects_top_25&apos;, &apos;string&apos;), (&apos;culture_objects_top_25_raion&apos;, &apos;int&apos;), (&apos;shopping_centers_raion&apos;, &apos;int&apos;), (&apos;office_raion&apos;, &apos;int&apos;), (&apos;thermal_power_plant_raion&apos;, &apos;string&apos;), (&apos;incineration_raion&apos;, &apos;string&apos;), (&apos;oil_chemistry_raion&apos;, &apos;string&apos;), (&apos;radiation_raion&apos;, &apos;string&apos;), (&apos;railroad_terminal_raion&apos;, &apos;string&apos;), (&apos;big_market_raion&apos;, &apos;string&apos;), (&apos;nuclear_reactor_raion&apos;, &apos;string&apos;), (&apos;detention_facility_raion&apos;, &apos;string&apos;), (&apos;full_all&apos;, &apos;int&apos;), (&apos;male_f&apos;, &apos;int&apos;), (&apos;female_f&apos;, &apos;int&apos;), (&apos;young_all&apos;, &apos;int&apos;), (&apos;young_male&apos;, &apos;int&apos;), (&apos;young_female&apos;, &apos;int&apos;), (&apos;work_all&apos;, &apos;int&apos;), (&apos;work_male&apos;, &apos;int&apos;), (&apos;work_female&apos;, &apos;int&apos;), (&apos;ekder_all&apos;, &apos;int&apos;), (&apos;ekder_male&apos;, &apos;int&apos;), (&apos;ekder_female&apos;, &apos;int&apos;), (&apos;0_6_all&apos;, &apos;int&apos;), (&apos;0_6_male&apos;, &apos;int&apos;), (&apos;0_6_female&apos;, &apos;int&apos;), (&apos;7_14_all&apos;, &apos;int&apos;), (&apos;7_14_male&apos;, &apos;int&apos;), (&apos;7_14_female&apos;, &apos;int&apos;), (&apos;0_17_all&apos;, &apos;int&apos;), (&apos;0_17_male&apos;, &apos;int&apos;), (&apos;0_17_female&apos;, &apos;int&apos;), (&apos;16_29_all&apos;, &apos;int&apos;), (&apos;16_29_male&apos;, &apos;int&apos;), (&apos;16_29_female&apos;, &apos;int&apos;), (&apos;0_13_all&apos;, &apos;int&apos;), (&apos;0_13_male&apos;, &apos;int&apos;), (&apos;0_13_female&apos;, &apos;int&apos;), (&apos;raion_build_count_with_material_info&apos;, &apos;string&apos;), (&apos;build_count_block&apos;, &apos;string&apos;), (&apos;build_count_wood&apos;, &apos;string&apos;), (&apos;build_count_frame&apos;, &apos;string&apos;), (&apos;build_count_brick&apos;, &apos;string&apos;), (&apos;build_count_monolith&apos;, &apos;string&apos;), (&apos;build_count_panel&apos;, &apos;string&apos;), (&apos;build_count_foam&apos;, &apos;string&apos;), (&apos;build_count_slag&apos;, &apos;string&apos;), (&apos;build_count_mix&apos;, &apos;string&apos;), (&apos;raion_build_count_with_builddate_info&apos;, &apos;string&apos;), (&apos;build_count_before_1920&apos;, &apos;string&apos;), (&apos;build_count_1921-1945&apos;, &apos;string&apos;), (&apos;build_count_1946-1970& ...

# %%
# Wide representation of the data in one table
## Macro adds supplemental data to sberbank_housing
sberbank_housing = sberbank_housing.withColumnRenamed('timestamp', 'sberbank_timestamp').select("*")
macro = macro.withColumnRenamed('timestamp', 'macro_timestamp').select('*')
sberbank_housing_macro = sberbank_housing.join(macro, 
                                               sberbank_housing.sberbank_timestamp == macro.macro_timestamp, 
                                               'left_outer')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(sberbank_housing_macro.count())
print(sberbank_housing_macro.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">30471
# [&apos;id&apos;, &apos;sberbank_timestamp&apos;, &apos;full_sq&apos;, &apos;life_sq&apos;, &apos;floor&apos;, &apos;max_floor&apos;, &apos;material&apos;, &apos;build_year&apos;, &apos;num_room&apos;, &apos;kitch_sq&apos;, &apos;state&apos;, &apos;product_type&apos;, &apos;sub_area&apos;, &apos;area_m&apos;, &apos;raion_popul&apos;, &apos;green_zone_part&apos;, &apos;indust_part&apos;, &apos;children_preschool&apos;, &apos;preschool_quota&apos;, &apos;preschool_education_centers_raion&apos;, &apos;children_school&apos;, &apos;school_quota&apos;, &apos;school_education_centers_raion&apos;, &apos;school_education_centers_top_20_raion&apos;, &apos;hospital_beds_raion&apos;, &apos;healthcare_centers_raion&apos;, &apos;university_top_20_raion&apos;, &apos;sport_objects_raion&apos;, &apos;additional_education_raion&apos;, &apos;culture_objects_top_25&apos;, &apos;culture_objects_top_25_raion&apos;, &apos;shopping_centers_raion&apos;, &apos;office_raion&apos;, &apos;thermal_power_plant_raion&apos;, &apos;incineration_raion&apos;, &apos;oil_chemistry_raion&apos;, &apos;radiation_raion&apos;, &apos;railroad_terminal_raion&apos;, &apos;big_market_raion&apos;, &apos;nuclear_reactor_raion&apos;, &apos;detention_facility_raion&apos;, &apos;full_all&apos;, &apos;male_f&apos;, &apos;female_f&apos;, &apos;young_all&apos;, &apos;young_male&apos;, &apos;young_female&apos;, &apos;work_all&apos;, &apos;work_male&apos;, &apos;work_female&apos;, &apos;ekder_all&apos;, &apos;ekder_male&apos;, &apos;ekder_female&apos;, &apos;0_6_all&apos;, &apos;0_6_male&apos;, &apos;0_6_female&apos;, &apos;7_14_all&apos;, &apos;7_14_male&apos;, &apos;7_14_female&apos;, &apos;0_17_all&apos;, &apos;0_17_male&apos;, &apos;0_17_female&apos;, &apos;16_29_all&apos;, &apos;16_29_male&apos;, &apos;16_29_female&apos;, &apos;0_13_all&apos;, &apos;0_13_male&apos;, &apos;0_13_female&apos;, &apos;raion_build_count_with_material_info&apos;, &apos;build_count_block&apos;, &apos;build_count_wood&apos;, &apos;build_count_frame&apos;, &apos;build_count_brick&apos;, &apos;build_count_monolith&apos;, &apos;build_count_panel&apos;, &apos;build_count_foam&apos;, &apos;build_count_slag&apos;, &apos;build_count_mix&apos;, &apos;raion_build_count_with_builddate_info&apos;, &apos;build_count_before_1920&apos;, &apos;build_count_1921-1945&apos;, &apos;build_count_1946-1970&apos;, &apos;build_count_1971-1995&apos;, &apos;build_count_after_1995&apos;, &apos;ID_metro&apos;, &apos;metro_min_avto&apos;, &apos;metro_km_avto&apos;, &apos;metro_min_walk&apos;, &apos;metro_km_walk&apos;, &apos;kindergarten_km&apos;, &apos;school_km&apos;, &apos;park_km&apos;, &apos;green_zone_km&apos;, &apos;industrial_km&apos;, &apos;water_treatment_km&apos;, &apos;cemetery_km&apos;, &apos;incineration_km&apos;, &apos;railroad_station_walk_km&apos;, &apos;railroad_station_walk_min&apos;, &apos;ID_railroad_station_walk&apos;, &apos;railroad_station_avto_km&apos;, &apos;railroad_station_avto_min&apos;, &apos;ID_railroad_station_avto&apos;, &apos;public_transport_station_km&apos;, &apos;public_transport_station_min_walk&apos;, &apos;water_km&apos;, &apos;water_1line&apos;, &apos;mkad_km&apos;, &apos;ttk_km&apos;, &apos;sadovoe_km&apos;, &apos;bulvar_ring_km&apos;, &apos;kremlin_km&apos;, &apos;big_road1_km&apos;, &apos;ID_big_road1&apos;, &apos;big_road1_1line&apos;, &apos;big_road2_km&apos;, &apos;ID_big_road2&apos;, &apos;railroad_km&apos;, &apos;railroad_1line&apos;, &apos;zd_vokzaly_avto_km&apos;, &apos;ID_railroad_terminal&apos;, &apos;bus_terminal_avto_km&apos;, &apos;ID_bus_terminal&apos;, &apos;oil_chemistry_km&apos;, &apos;nuclear_reactor_km&apos;, &apos;radiation_km&apos;, &apos;power_transmission_line_km&apos;, &apos;thermal_power_plant_km&apos;, &apos;ts_km&apos;, &apos;big_market_km&apos;, &apos;market_shop_km&apos;, &apos;fitness_km&apos;, &apos;swim_pool_km&apos;, &apos;ice_rink_km&apos;, &apos;stadium_km&apos;, &apos;basketball_km&apos;, &apos;hospice_morgue_km&apos;, &apos;detention_facility_km&apos;, & ...

# %%
sberbank_housing_macro.createOrReplaceTempView("sberbank_housing_macro")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT *
FROM sberbank_housing_macro
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>sberbank_timestamp</th><th>full_sq</th><th>life_sq</th><th>floor</th><th>max_floor</th><th>material</th><th>build_year</th><th>num_room</th><th>kitch_sq</th><th>state</th><th>product_type</th><th>sub_area</th><th>area_m</th><th>raion_popul</th><th>green_zone_part</th><th>indust_part</th><th>children_preschool</th><th>preschool_quota</th><th>preschool_education_centers_raion</th><th>children_school</th><th>school_quota</th><th>school_education_centers_raion</th><th>school_education_centers_top_20_raion</th><th>hospital_beds_raion</th><th>healthcare_centers_raion</th><th>university_top_20_raion</th><th>sport_objects_raion</th><th>additional_education_raion</th><th>culture_objects_top_25</th><th>culture_objects_top_25_raion</th><th>shopping_centers_raion</th><th>office_raion</th><th>thermal_power_plant_raion</th><th>incineration_raion</th><th>oil_chemistry_raion</th><th>radiation_raion</th><th>railroad_terminal_raion</th><th>big_market_raion</th><th>nuclear_reactor_raion</th><th>detention_facility_raion</th><th>full_all</th><th>male_f</th><th>female_f</th><th>young_all</th><th>young_male</th><th>young_female</th><th>work_all</th><th>work_male</th><th>work_female</th><th>ekder_all</th><th>ekder_male</th><th>ekder_female</th><th>0_6_all</th><th>0_6_male</th><th>0_6_female</th><th>7_14_all</th><th>7_14_male</th><th>7_14_female</th><th>0_17_all</th><th>0_17_male</th><th>0_17_female</th><th>16_29_all</th><th>16_29_male</th><th>16_29_female</th><th>0_13_all</th><th>0_13_male</th><th>0_13_female</th><th>raion_build_count_with_material_info</th><th>build_count_block</th><th>build_count_wood</th><th>build_count_frame</th><th>build_count_brick</th><th>build_count_monolith</th><th>build_count_panel</th><th>build_count_foam</th><th>build_count_slag</th><th>build_count_mix</th><th>raion_build_count_with_builddate_info</th><th>build_count_before_1920</th><th>build_count_1921-1945</th><th>build_count_1946-1970</th><th>build_count_1971-1995</th><th>build_count_after_1995</th><th>ID_metro</th><th>metro_min_avto</th><th>metro_km_avto</th><th>metro_min_walk</th><th>metro_km_walk</th><th>kindergarten_km</th><th>school_km</th><th>park_km</th><th>green_zone_km</th><th>industrial_km</th><th>water_treatment_km</th><th>cemetery_km</th><th>incineration_km</th><th>railroad_station_walk_km</th><th>railroad_station_walk_min</th><th>ID_railroad_station_walk</th><th>railroad_station_avto_km</th><th>railroad_station_avto_min</th><th>ID_railroad_station_avto</th><th>public_transport_station_km</th><th>public_transport_station_min_walk</th><th>water_km</th><th>water_1line</th><th>mkad_km</th><th>ttk_km</th><th>sadovoe_km</th><th>bulvar_ring_km</th><th>kremlin_km</th><th>big_road1_km</th><th>ID_big_road1</th><th>big_road1_1line</th><th>big_road2_km</th><th>ID_big_road2</th><th>railroad_km</th><th>railroad_1line</th><th>zd_vokzaly_avto_km</th><th>ID_railroad_terminal</th><th>bus_terminal_avto_km</th><th>ID_bus_terminal</th><th>oil_chemistry_km</th><th>nuclear_reactor_km</th><th>radiation_km</th><th>power_transmission_line_km</th><th>thermal_power_plant_km</th><th>ts_km</th><th>big_market_km</th><th>market_shop_km</th><th>fitness_km</th><th>swim_pool_km</th><th>ice_rink_km</th><th>stadium_km</th><th>basketball_km</th><th>hospice_morgue_km</th><th>detention_facility_km</th><th>public_healthcare_km</th><th>university_km</th><th>workplaces_km</th><th>shopping_centers_km</th><th>office_km</th><th>additional_education_km</th><th>preschool_km</th><th>big_church_km</th><th>church_synagogue_km</th><th>mosque_km</th><th>theater_km</th><th>museum_km</th><th>exhibition_km</th><th>catering_km</th><th>ecology</th><th>green_part_500</th><th>prom_part_500</th><th>office_count_500</th><th>office_sqm_500</th><th>trc_count_500</th><th>trc_sqm_500</th><th>cafe_count_500</th><th>cafe_sum_500_min_price_avg</th><th>cafe_sum_500_max_price_avg</th><th>cafe_avg_p ...

# %%
spark.catalog.dropTempView("sberbank_housing_macro")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Persist this wide dataset that has not been altered yet

permanent_table_name = "sberbank_housing_macro"
sberbank_housing_macro.write.format("parquet").mode('overwrite').saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## FEATURE ENGINEERING
# ### PARQUET -> PARQUET

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType, IntegerType

def yn_conversion(val):
  if str(val).lower() == 'yes':
    return 1
  elif str(val).lower() == 'no':
    return 0
  elif str(val).lower() == 'y':
    return 1
  elif str(val).lower() == 'n':
    return 0
  else:
    return None

    
to_none_udf = udf(lambda val: None if val == "NA" else val, StringType())
yn_conversion_udf = udf(lambda val: yn_conversion(val), IntegerType())

spark.udf.register("to_none_udf", to_none_udf)
spark.udf.register("yn_conversion_udf", yn_conversion_udf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">79</span><span class="ansired">]: </span>&lt;function __main__.&lt;lambda&gt;&gt;
# </div>

# %%
# %sql
SELECT *
FROM sberbank_housing_macro
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>sberbank_timestamp</th><th>full_sq</th><th>life_sq</th><th>floor</th><th>max_floor</th><th>material</th><th>build_year</th><th>num_room</th><th>kitch_sq</th><th>state</th><th>product_type</th><th>sub_area</th><th>area_m</th><th>raion_popul</th><th>green_zone_part</th><th>indust_part</th><th>children_preschool</th><th>preschool_quota</th><th>preschool_education_centers_raion</th><th>children_school</th><th>school_quota</th><th>school_education_centers_raion</th><th>school_education_centers_top_20_raion</th><th>hospital_beds_raion</th><th>healthcare_centers_raion</th><th>university_top_20_raion</th><th>sport_objects_raion</th><th>additional_education_raion</th><th>culture_objects_top_25</th><th>culture_objects_top_25_raion</th><th>shopping_centers_raion</th><th>office_raion</th><th>thermal_power_plant_raion</th><th>incineration_raion</th><th>oil_chemistry_raion</th><th>radiation_raion</th><th>railroad_terminal_raion</th><th>big_market_raion</th><th>nuclear_reactor_raion</th><th>detention_facility_raion</th><th>full_all</th><th>male_f</th><th>female_f</th><th>young_all</th><th>young_male</th><th>young_female</th><th>work_all</th><th>work_male</th><th>work_female</th><th>ekder_all</th><th>ekder_male</th><th>ekder_female</th><th>0_6_all</th><th>0_6_male</th><th>0_6_female</th><th>7_14_all</th><th>7_14_male</th><th>7_14_female</th><th>0_17_all</th><th>0_17_male</th><th>0_17_female</th><th>16_29_all</th><th>16_29_male</th><th>16_29_female</th><th>0_13_all</th><th>0_13_male</th><th>0_13_female</th><th>raion_build_count_with_material_info</th><th>build_count_block</th><th>build_count_wood</th><th>build_count_frame</th><th>build_count_brick</th><th>build_count_monolith</th><th>build_count_panel</th><th>build_count_foam</th><th>build_count_slag</th><th>build_count_mix</th><th>raion_build_count_with_builddate_info</th><th>build_count_before_1920</th><th>build_count_1921-1945</th><th>build_count_1946-1970</th><th>build_count_1971-1995</th><th>build_count_after_1995</th><th>ID_metro</th><th>metro_min_avto</th><th>metro_km_avto</th><th>metro_min_walk</th><th>metro_km_walk</th><th>kindergarten_km</th><th>school_km</th><th>park_km</th><th>green_zone_km</th><th>industrial_km</th><th>water_treatment_km</th><th>cemetery_km</th><th>incineration_km</th><th>railroad_station_walk_km</th><th>railroad_station_walk_min</th><th>ID_railroad_station_walk</th><th>railroad_station_avto_km</th><th>railroad_station_avto_min</th><th>ID_railroad_station_avto</th><th>public_transport_station_km</th><th>public_transport_station_min_walk</th><th>water_km</th><th>water_1line</th><th>mkad_km</th><th>ttk_km</th><th>sadovoe_km</th><th>bulvar_ring_km</th><th>kremlin_km</th><th>big_road1_km</th><th>ID_big_road1</th><th>big_road1_1line</th><th>big_road2_km</th><th>ID_big_road2</th><th>railroad_km</th><th>railroad_1line</th><th>zd_vokzaly_avto_km</th><th>ID_railroad_terminal</th><th>bus_terminal_avto_km</th><th>ID_bus_terminal</th><th>oil_chemistry_km</th><th>nuclear_reactor_km</th><th>radiation_km</th><th>power_transmission_line_km</th><th>thermal_power_plant_km</th><th>ts_km</th><th>big_market_km</th><th>market_shop_km</th><th>fitness_km</th><th>swim_pool_km</th><th>ice_rink_km</th><th>stadium_km</th><th>basketball_km</th><th>hospice_morgue_km</th><th>detention_facility_km</th><th>public_healthcare_km</th><th>university_km</th><th>workplaces_km</th><th>shopping_centers_km</th><th>office_km</th><th>additional_education_km</th><th>preschool_km</th><th>big_church_km</th><th>church_synagogue_km</th><th>mosque_km</th><th>theater_km</th><th>museum_km</th><th>exhibition_km</th><th>catering_km</th><th>ecology</th><th>green_part_500</th><th>prom_part_500</th><th>office_count_500</th><th>office_sqm_500</th><th>trc_count_500</th><th>trc_sqm_500</th><th>cafe_count_500</th><th>cafe_sum_500_min_price_avg</th><th>cafe_sum_500_max_price_avg</th><th>cafe_avg_p ...

# %%
# Select features of interest and engineer features.
engineered_df = spark.sql("""SELECT
                                year(sberbank_timestamp) as year,
                                month(sberbank_timestamp) as month,
                                day(sberbank_timestamp) as day,
                                full_sq,
                                life_sq,
                                floor,
                                upper(sub_area) as sub_area,            --normalize in case of capitalization diffs
                                upper(product_type) as product_type,    --normalize in case of capitalization diffs
                                to_none_udf(max_floor) as max_floor,
                                to_none_udf(material) as material,
                                to_none_udf(build_year) as build_year,
                                yn_conversion_udf(big_market_raion) as big_market_raion,
                                yn_conversion_udf(nuclear_reactor_raion) as nuclear_reactor_raion,
                                yn_conversion_udf(detention_facility_raion) as detention_facility_raion,
                                cast(work_all as Double) as work_all
                           FROM sberbank_housing_macro""")
engineered_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+-------+-------+-----+-----------------+------------+---------+--------+----------+----------------+---------------------+------------------------+--------+
# year|month|day|full_sq|life_sq|floor|         sub_area|product_type|max_floor|material|build_year|big_market_raion|nuclear_reactor_raion|detention_facility_raion|work_all|
# +----+-----+---+-------+-------+-----+-----------------+------------+---------+--------+----------+----------------+---------------------+------------------------+--------+
# 2011|    8| 20|     43|     27|    4|         BIBIREVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 98207.0|
# 2011|    8| 23|     34|     19|    3|NAGATINSKIJ ZATON|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 70194.0|
# 2011|    8| 27|     43|     29|    2|   TEKSTIL&apos;SHHIKI|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 63388.0|
# 2011|    9|  1|     89|     50|    9|           MITINO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0|120381.0|
# 2011|    9|  5|     77|     77|    4|        BASMANNOE|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 68043.0|
# 2011|    9|  6|     67|     46|   14|   NIZHEGORODSKOE|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 29660.0|
# 2011|    9|  8|     25|     14|   10|       SOKOL&apos;NIKI|  INVESTMENT|     null|    null|      null|               0|                    0|                       1| 35003.0|
# 2011|    9|  9|     44|     44|    5|         BIBIREVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 98207.0|
# 2011|    9| 10|     42|     27|    5|          KOPTEVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 59120.0|
# 2011|    9| 13|     36|     21|    9|          KUNCEVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 85551.0|
# 2011|    9| 16|     36|     19|   12| KOSINO-UHTOMSKOE|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 49242.0|
# 2011|    9| 16|     38|     19|   11|ZAPADNOE DEGUNINO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 51138.0|
# 2011|    9| 17|     43|     28|    4|          KUNCEVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 85551.0|
# 2011|    9| 19|     31|     31|    4|      PRESNENSKOE|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 75357.0|
# 2011|    9| 19|     31|     21|    3|        LEFORTOVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       1| 58895.0|
# 2011|    9| 20|     51|     31|   15|          MAR&apos;INO|  INVESTMENT|     null|    null|      null|               0|                    0|                       1|161290.0|
# 2011|    9| 20|     47|     31|    4|        KUZ&apos;MINKI|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 93811.0|
# 2011|    9| 20|     42|     28|    2|         NAGORNOE|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 49882.0|
# 2011|    9| 22|     59|     33|   10| KOSINO-UHTOMSKOE|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 49242.0|
# 2011|    9| 22|     44|     29|    4|       GOL&apos;JANOVO|  INVESTMENT|     null|    null|      null|               0|                    0|                       0| 98260.0|
# +----+-----+---+-------+-------+-----+-----------------+------------+---------+--------+----------+----------------+---------------------+------------------------+--------+
# only showing top 20 rows
#
# </div>

# %%
# Persist this engineered dataset

permanent_table_name = "sberbank_train_01"
engineered_df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
